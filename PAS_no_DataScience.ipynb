# %%
print("")
total = 3 / 6
print("hasil1 = " + str(total))

total2 = 2 / 6
print("hasil2 = " + str(total2))

total3 = 4 / 6
print("hasil3 = " + str(total3))

total4 = 5 / 6
print("hasil4 = " + str(total4))

total5 = 6 / 6
print("hasil5 = " + str(total5))

total6 = 1 / 6
print("hasil6 = " + str(total6))

total7 = 5 / 6
print("hasil7 = " + str(total7))

total8 = 6 / 6
print("hasil8 = " + str(total8))

total9 = 3 / 6
print("hasil9 = " + str(total9))

total10 = 2 / 6
print("hasil10 = " + str(total10))

total11 = 2 / 6
print("hasil11 = " + str(total11))

total12 = 1 / 6
print("hasil12 = " + str(total12))

total13 = 3 / 6
print("hasil13 = " + str(total13))

total14 = 1 / 6
print("hasil14 = " + str(total14))

total15 = 5 / 6
print("hasil5=15 = " + str(total15))

hasil = total + total2 + total3 + total4 + total5 + total6 + total7 + total8 + total9 + total10 + total11 + total12 + total13 + total14 + total15
print("maka totalnya = "+ str(hasil))
# Out:
# hasil1 = 0.5
# hasil2 = 0.3333333333333333
# hasil3 = 0.6666666666666666
# hasil4 = 0.8333333333333334
# hasil5 = 1.0
# hasil6 = 0.16666666666666666
# hasil7 = 0.8333333333333334
# hasil8 = 1.0
# hasil9 = 0.5
# hasil10 = 0.3333333333333333
# hasil11 = 0.3333333333333333
# hasil12 = 0.16666666666666666
# hasil13 = 0.5
# hasil14 = 0.16666666666666666
# hasil5=15 = 0.8333333333333334
# maka totalnya = 8.166666666666666

# %%
total = 3 / 4
print("hasil1 = " + str(total))

total2 = 2 / 4
print("hasil2 = " + str(total2))

total3 = 4 / 4
print("hasil3 = " + str(total3))

total6 = 1 / 4
print("hasil6 = " + str(total6))

total9 = 3 / 4
print("hasil9 = " + str(total9))

total10 = 2 / 4
print("hasil10 = " + str(total10))

total11 = 2 / 4
print("hasil11 = " + str(total11))

total12 = 1 / 4
print("hasil12 = " + str(total12))

total13 = 3 / 4
print("hasil13 = " + str(total13))

total14 = 1 / 4
print("hasil14 = " + str(total14))

hasil = total + total2 + total3 + total6 + total9 + total10 + total11 + total12 + total13 + total14
print("maka totalnya = "+ str(hasil))
# Out:
# hasil1 = 0.75
# hasil2 = 0.5
# hasil3 = 1.0
# hasil6 = 0.25
# hasil9 = 0.75
# hasil10 = 0.5
# hasil11 = 0.5
# hasil12 = 0.25
# hasil13 = 0.75
# hasil14 = 0.25
# maka totalnya = 5.5

# %%
print("")
total = 9 / 12
print("hasil1 = " + str(total))

total2 = 11 / 12
print("hasil2 = " + str(total2))

total3 = 3 / 12
print("hasil3 = " + str(total3))

total4 = 6 / 12
print("hasil4 = " + str(total4))

total5 = 2 / 12
print("hasil5 = " + str(total5))

total6 = 4 / 12
print("hasil6 = " + str(total6))

total7 = 9 / 12
print("hasil7 = " + str(total7))

total8 = 12 / 12
print("hasil8 = " + str(total8))

total9 = 10 / 12
print("hasil9 = " + str(total9))

total10 = 8 / 12
print("hasil10 = " + str(total10))

total11 = 2 / 12
print("hasil11 = " + str(total11))

total12 = 6 / 12
print("hasil12 = " + str(total12))

total13 = 3 / 12
print("hasil13 = " + str(total13))

total14 = 4 / 12
print("hasil14 = " + str(total14))

total15 = 9 / 12
print("hasil15 = " + str(total15))

total16 = 8 / 12
print("hasil16 = " + str(total16))

total17 = 5 / 12
print("hasil17 = " + str(total17))

total18 = 6 / 12
print("hasil18 = " + str(total18))

total19 = 11 / 12
print("hasil19 = " + str(total19))

total20 = 10 / 12
print("hasil20 = " + str(total20))


hasil = total + total2 + total3 + total4 + total5 + total6 + total7 + total8 + total9 + total10 + total11 + total12 + total13 + total14 + total15 + total16 + total17 + total18 + total19 + total20
print("maka totalnya = "+ str(hasil))
# Out:
# hasil1 = 0.75
# hasil2 = 0.9166666666666666
# hasil3 = 0.25
# hasil4 = 0.5
# hasil5 = 0.16666666666666666
# hasil6 = 0.3333333333333333
# hasil7 = 0.75
# hasil8 = 1.0
# hasil9 = 0.8333333333333334
# hasil10 = 0.6666666666666666
# hasil11 = 0.16666666666666666
# hasil12 = 0.5
# hasil13 = 0.25
# hasil14 = 0.3333333333333333
# hasil15 = 0.75
# hasil16 = 0.6666666666666666
# hasil17 = 0.4166666666666667
# hasil18 = 0.5
# hasil19 = 0.9166666666666666
# hasil20 = 0.8333333333333334
# maka totalnya = 11.499999999999998

# %%
total4 = 6 / 6
print("hasil4 = " + str(total4))

total5 = 2 / 6
print("hasil5 = " + str(total5))

total6 = 4 / 6
print("hasil6 = " + str(total6))

total8 = 12 / 6
print("hasil8 = " + str(total8))

total9 = 10 / 6
print("hasil9 = " + str(total9))

total10 = 8 / 6
print("hasil10 = " + str(total10))

total11 = 2 / 6
print("hasil11 = " + str(total11))

total12 = 6 / 6
print("hasil12 = " + str(total12))

total14 = 4 / 6
print("hasil14 = " + str(total14))

total16 = 8 / 6
print("hasil16 = " + str(total16))

total18 = 6 / 6
print("hasil18 = " + str(total18))

total20 = 10 / 6
print("hasil20 = " + str(total20))


hasil = total4 + total5 + total6 + total7 + total8 + total9 + total10 + total11 + total12 + total14 + total16 + total18 
print("maka totalnya = "+ str(hasil))
# Out:
# hasil4 = 1.0
# hasil5 = 0.3333333333333333
# hasil6 = 0.6666666666666666
# hasil8 = 2.0
# hasil9 = 1.6666666666666667
# hasil10 = 1.3333333333333333
# hasil11 = 0.3333333333333333
# hasil12 = 1.0
# hasil14 = 0.6666666666666666
# hasil16 = 1.3333333333333333
# hasil18 = 1.0
# hasil20 = 1.6666666666666667
# maka totalnya = 12.083333333333334

# %%
print("----------No 2--------------")
minggu1 = 6560860 + 5950850 + 12685900 + 5768500 + 2989000
print("maka totalnya "+str(minggu1))

minggu2 = 8782150 + 6620000 + 5128750 + 5217300 + 4820600
print("maka totalnya "+str(minggu2))

minggu3 = 8130940 + 2940650 + 3488200 + 6930540 + 4319260
print("maka hasinya "+str(minggu3))

minggu4 = 12849100 + 5752200 + 5128400 + 3880490 + 4982100
print("maka hasilnya "+str(minggu4))

print("")

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ["minggu1", "minggu2", "minggu3", "minggu4"]
jumlah = [33955110, 30568800, 25809590, 32592290]
c = ['blue', 'green', 'red', 'purple']
plt.title("total")
plt.bar(eskul, jumlah, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ["minggu1", "minggu2", "minggu3", "minggu4"]
jumlah = [33955110, 30568800, 25809590, 32592290]
ax.pie(jumlah, labels=eskul,autopct='%1.2f%%')
plt.title("total")
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ["minggu1", "minggu2", "minggu3", "minggu4"]
jumlah = [33955110, 30568800, 25809590, 32592290]
c = ['blue', 'green', 'red', 'purple']
plt.title("total")
plt.scatter(eskul, jumlah, color = c)
plt.show()
# Out:
# ----------No 2--------------
# maka totalnya 33955110
# maka totalnya 30568800
# maka hasinya 25809590
# maka hasilnya 32592290

# %%
minggu1 = (386 + 752 + 1203 + 715 + 289) / 5 
print("Rata rata minggu1 " +str(minggu1))

minggu2 = (454 + 781 + 634 + 659 + 411) / 5
print("Rata rata minggu2 " +str(minggu2))

minggu3 = (599 + 338 + 442 + 872 + 390) / 5
print("Rata rata minggu3 " +str(minggu3))

minggu4 = (867 + 512 + 650 + 492 + 488) / 5
print("Rata rata minggu4 " +str(minggu4))
# Out:
# Rata rata minggu1 669.0
# Rata rata minggu2 587.8
# Rata rata minggu3 528.2
# Rata rata minggu4 601.8

# %%
total = 180 + 164 + 218 + 156 + 92
print("totalnya = "+str(total))

senin = total / 10
print("maka hasilnya = "+str(senin))

selasa = total / 10
print("maka hasilnya = "+str(selasa))

rabu = total / 10
print("maka hasilnya = "+str(rabu))

kamis = total / 10
print("maka hasilnya = "+str(kamis))

jumat = total / 10
print("maka hasilnya = "+str(jumat))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat 
print("maka jumlahnya = "+str(jumlah))
print("=======================")
sabtu = 405 / 2
print("maka hasilnya = "+str(sabtu))

minggu = 405 / 2
print("maka hasilnya = "+str(minggu))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("maka jumlahnya = "+str(jumlah))

print("")
print("=====minggu2=======")
total = 156 + 212 + 164 + 144 + 138
print("totalnya = "+str(total))

senin = total / 10
print("maka hasilnya = "+str(senin))

selasa = total / 10
print("maka hasilnya = "+str(selasa))

rabu = total / 10
print("maka hasilnya = "+str(rabu))

kamis = total / 10
print("maka hasilnya = "+str(kamis))

jumat = total / 10
print("maka hasilnya = "+str(jumat))
print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat 
print("maka jumlahnya = "+str(jumlah))
print("=======================")

sabtu = 407 / 2
print("maka hasilnya = "+str(sabtu))

minggu = 407 / 2
print("maka hasilnya = "+str(minggu))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("maka jumlahnya = "+str(jumlah))

print("")
print("=====minggu3=======")
total = 290 + 95 + 120 + 225 + 135
print("totalnya = "+str(total))

senin = total / 10
print("maka hasilnya = "+str(senin))

selasa = total / 10
print("maka hasilnya = "+str(selasa))

rabu = total / 10
print("maka hasilnya = "+str(rabu))

kamis = total / 10
print("maka hasilnya = "+str(kamis))

jumat = total / 10
print("maka hasilnya = "+str(jumat))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat 
print("maka jumlahnya = "+str(jumlah))
print("=======================")

sabtu = 432 / 2
print("maka hasilnya = "+str(sabtu))

minggu = 432 / 2
print("maka hasilnya = "+str(minggu))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("maka jumlahnya = "+str(jumlah))

print("")
print("=====minggu4=======")
total = 350 + 143 + 201 + 174 + 205
print("totalnya = "+str(total))

senin = total / 10
print("maka hasilnya = "+str(senin))

selasa = total / 10
print("maka hasilnya = "+str(selasa))

rabu = total / 10
print("maka hasilnya = "+str(rabu))

kamis = total / 10
print("maka hasilnya = "+str(kamis))

jumat = total / 10
print("maka hasilnya = "+str(jumat))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat 
print("maka jumlahnya = "+str(jumlah))
print("=======================")

sabtu = 536 / 2
print("maka hasilnya = "+str(sabtu))

minggu = 536 / 2
print("maka hasilnya = "+str(minggu))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("maka jumlahnya = "+str(jumlah))
# Out:
# totalnya = 810
# maka hasilnya = 81.0
# maka hasilnya = 81.0
# maka hasilnya = 81.0
# maka hasilnya = 81.0
# maka hasilnya = 81.0
# ...
# maka jumlahnya = 405.0
# ...
# maka hasilnya = 202.5
# maka hasilnya = 202.5
# ...
# maka jumlahnya = 810.0
#
# =====minggu2=======
# totalnya = 814
# maka hasilnya = 81.4
# maka hasilnya = 81.4
# maka hasilnya = 81.4
# maka hasilnya = 81.4
# maka hasilnya = 81.4
# ...
# maka jumlahnya = 407.0
# ...
# maka hasilnya = 203.5
# maka hasilnya = 203.5
# ...
# maka jumlahnya = 814.0
#
# =====minggu3=======
# totalnya = 865
# maka hasilnya = 86.5
# maka hasilnya = 86.5
# maka hasilnya = 86.5
# maka hasilnya = 86.5
# maka hasilnya = 86.5
# ...
# maka jumlahnya = 432.5
# ...
# maka hasilnya = 216.0
# maka hasilnya = 216.0
# ...
# maka jumlahnya = 864.5
#
# =====minggu4=======
# totalnya = 1073
# maka hasilnya = 107.3
# maka hasilnya = 107.3
# maka hasilnya = 107.3
# maka hasilnya = 107.3
# maka hasilnya = 107.3
# ...
# maka jumlahnya = 536.5
# ...
# maka hasilnya = 268.0
# maka hasilnya = 268.0
# ...
# maka jumlahnya = 1072.5

# %%
total = 6560860 + 5950850 + 12685900 + 5768500 + 2989000
print("maka totalnya = "+str(total))

senin = total / 10
print("maka jumlah nya = "+str(senin))

selasa = total / 10
print("maka jumlah nya = "+str(selasa))

rabu = total / 10
print("maka jumlah nya = "+str(rabu))

kamis = total / 10
print("maka jumlah nya = "+str(kamis))

jumat = total / 10
print("maka jumlah nya = "+str(jumat))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat 
print("maka jumlahnya = "+str(jumlah))
print("=======================")

sabtu = 16977555 / 2
print("maka jumlah nya = "+str(sabtu))

minggu = 16977555 / 2
print("maka jumlah nya = "+str(minggu))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("maka jumlahnya = "+str(jumlah))

print("")
print("=====minggu2=======")
total = 8782150 + 6620000 + 5128750 + 5217300 + 4820600
print("totalnya = "+str(total))

senin = total / 10
print("maka hasilnya = "+str(senin))

selasa = total / 10
print("maka hasilnya = "+str(selasa))

rabu = total / 10
print("maka hasilnya = "+str(rabu))

kamis = total / 10
print("maka hasilnya = "+str(kamis))

jumat = total / 10
print("maka hasilnya = "+str(jumat))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat 
print("maka jumlahnya = "+str(jumlah))
print("=======================")

sabtu = 15284400 / 2
print("maka hasilnya = "+str(sabtu))

minggu = 15284400 / 2
print("maka hasilnya = "+str(minggu))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("maka jumlahnya = "+str(jumlah))

print("")
print("=====minggu3=======")
total = 8130940 + 2940650 + 3488200 + 6930540 + 4319260
print("totalnya = "+str(total))

senin = total / 10
print("maka hasilnya = "+str(senin))

selasa = total / 10
print("maka hasilnya = "+str(selasa))

rabu = total / 10
print("maka hasilnya = "+str(rabu))

kamis = total / 10
print("maka hasilnya = "+str(kamis))

jumat = total / 10
print("maka hasilnya = "+str(jumat))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat 
print("maka jumlahnya = "+str(jumlah))
print("=======================")

sabtu = 12904795 / 2
print("maka hasilnya = "+str(sabtu))

minggu = 12904795 / 2
print("maka hasilnya = "+str(minggu))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("maka jumlahnya = "+str(jumlah))

print("")
print("=====minggu4=======")
total = 12849100 + 5752200 + 5128400 + 3880490 + 4982100
print("totalnya = "+str(total))

senin = total / 10
print("maka hasilnya = "+str(senin))

selasa = total / 10
print("maka hasilnya = "+str(selasa))

rabu = total / 10
print("maka hasilnya = "+str(rabu))

kamis = total / 10
print("maka hasilnya = "+str(kamis))

jumat = total / 10
print("maka hasilnya = "+str(jumat))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat 
print("maka jumlahnya = "+str(jumlah))
print("=======================")

sabtu = 16296145 / 2
print("maka hasilnya = "+str(sabtu))

minggu = 16296145 / 2
print("maka hasilnya = "+str(minggu))

print("=======================")
jumlah = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("maka jumlahnya = "+str(jumlah))
# Out:
# maka totalnya = 33955110
# maka jumlah nya = 3395511.0
# maka jumlah nya = 3395511.0
# maka jumlah nya = 3395511.0
# maka jumlah nya = 3395511.0
# maka jumlah nya = 3395511.0
# ...
# maka jumlahnya = 16977555.0
# ...
# maka jumlah nya = 8488777.5
# maka jumlah nya = 8488777.5
# ...
# maka jumlahnya = 33955110.0
#
# =====minggu2=======
# totalnya = 30568800
# maka hasilnya = 3056880.0
# maka hasilnya = 3056880.0
# maka hasilnya = 3056880.0
# maka hasilnya = 3056880.0
# maka hasilnya = 3056880.0
# ...
# maka jumlahnya = 15284400.0
# ...
# maka hasilnya = 7642200.0
# maka hasilnya = 7642200.0
# ...
# maka jumlahnya = 30568800.0
#
# =====minggu3=======
# totalnya = 25809590
# maka hasilnya = 2580959.0
# maka hasilnya = 2580959.0
# maka hasilnya = 2580959.0
# maka hasilnya = 2580959.0
# maka hasilnya = 2580959.0
# ...
# maka jumlahnya = 12904795.0
# ...
# maka hasilnya = 6452397.5
# maka hasilnya = 6452397.5
# ...
# maka jumlahnya = 25809590.0
#
# =====minggu4=======
# totalnya = 32592290
# maka hasilnya = 3259229.0
# ...

# %%
total = 386 + 752 + 1203 + 715 + 289 + 454 + 781 + 634 + 659 + 411 + 599 + 338 + 442 + 872 + 390 + 867 + 512 + 650 + 492 + 488
print("maka total penjualan = "+str(total))

hasil = 6560860 + 5950850 + 12685900 + 5768500 + 2989000 + 8782150 + 6620000 + 5128750 + 5217300 + 4820600 + 8130940 + 2940650 + 3488200 + 6930540 + 4319260 + 12849100 + 5752200 + 5128400 + 3880490 + 4982100
print("maka total pendapatan = "+str(hasil))

jumlah = total + hasil
print("maka total keseluruhannya = " +str(jumlah))
# Out:
# maka total penjualan = 11934
# maka total pendapatan = 122925790
# maka total keseluruhannya = 122937724
